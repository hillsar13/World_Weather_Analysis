# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(10)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_des = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "City Description": city_des})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
    
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | ust-tsilma
# Processing Record 4 of Set 1 | camacha
# Processing Record 5 of Set 1 | maceio
# Processing Record 6 of Set 1 | lubango
# Processing Record 7 of Set 1 | leh
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | muzhi
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | point fortin
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | ayorou
# Processing Record 19 of Set 1 | bathsheba
# Processing Record 20 of Set 1 | tabriz
# Processing Record 21 of Set 1 | okakarara
# Processing Record 22 of Set 1 | hirara
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | finschhafen
# Processing Record 26 of Set 1 | meadow lake
# Processing Record 27 of Set 1 | shingu
# Processing Record 28 of Set 1 | markova
# Processing Record 29 of Set 1 | louisbourg
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | honningsvag
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | soller
# Processing Record 35 of Set 1 | ambon
# Processing Record 36 of Set 1 | khatanga
# Processing Record 37 of Set 1 | tuatapere
# Processing Record 38 of Set 1 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 1 | berlevag
# Processing Record 40 of Set 1 | diffa
# Processing Record 41 of Set 1 | nedjo
# Processing Record 42 of Set 1 | alofi
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | tevaitoa
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | zeya
# Processing Record 47 of Set 1 | faanui
# Processing Record 48 of Set 1 | simpang empat
# Processing Record 49 of Set 1 | brae
# Processing Record 50 of Set 1 | alindao
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | kandi
# Processing Record 3 of Set 2 | komsomolskiy
# Processing Record 4 of Set 2 | broken hill
# Processing Record 5 of Set 2 | salalah
# Processing Record 6 of Set 2 | tarko-sale
# Processing Record 7 of Set 2 | margate
# Processing Record 8 of Set 2 | te anau
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | touros
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | tura
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | clyde river
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | jalu
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | ostrovnoy
# Processing Record 23 of Set 2 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 2 | victoria
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | san patricio
# Processing Record 27 of Set 2 | vanimo
# Processing Record 28 of Set 2 | lata
# Processing Record 29 of Set 2 | rocha
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | tubig indangan
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | khonuu
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 2 | deputatskiy
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 2 | waipawa
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | banda aceh
# Processing Record 40 of Set 2 | obo
# Processing Record 41 of Set 2 | padang
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | san luis
# Processing Record 46 of Set 2 | porbandar
# Processing Record 47 of Set 2 | tasiilaq
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | gunjur
# Processing Record 50 of Set 2 | ranong
# Processing Record 1 of Set 3 | hobart
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | makakilo city
# Processing Record 4 of Set 3 | hithadhoo
# Processing Record 5 of Set 3 | librazhd
# Processing Record 6 of Set 3 | aklavik
# Processing Record 7 of Set 3 | havre-saint-pierre
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | lavrentiya
# Processing Record 10 of Set 3 | toma
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | kota bahru
# Processing Record 14 of Set 3 | provideniya
# Processing Record 15 of Set 3 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 3 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 3 | sur
# Processing Record 18 of Set 3 | vila franca do campo
# Processing Record 19 of Set 3 | aksarka
# Processing Record 20 of Set 3 | pingliang
# Processing Record 21 of Set 3 | tarudant
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 3 | el faiyum
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 3 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 3 | the valley
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | mizan teferi
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | itupiranga
# Processing Record 29 of Set 3 | prince george
# Processing Record 30 of Set 3 | coihaique
# Processing Record 31 of Set 3 | poncitlan
# Processing Record 32 of Set 3 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 3 | alyangula
# Processing Record 34 of Set 3 | cockburn town
# Processing Record 35 of Set 3 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 3 | fuerte olimpo
# Processing Record 37 of Set 3 | port hardy
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | marzuq
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | chagda
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 3 | soe
# Processing Record 43 of Set 3 | cherskiy
# Processing Record 44 of Set 3 | zhezkazgan
# Processing Record 45 of Set 3 | yaan
# Processing Record 46 of Set 3 | san pedro
# Processing Record 47 of Set 3 | celendin
# Processing Record 48 of Set 3 | albany
# Processing Record 49 of Set 3 | cabo san lucas
# Processing Record 50 of Set 3 | juegang
# Processing Record 1 of Set 4 | rayong
# Processing Record 2 of Set 4 | olinala
# Processing Record 3 of Set 4 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 4 | bonthe
# Processing Record 5 of Set 4 | arraial do cabo
# Processing Record 6 of Set 4 | kiruna
# Processing Record 7 of Set 4 | antofagasta
# Processing Record 8 of Set 4 | belmonte
# Processing Record 9 of Set 4 | qaanaaq
# Processing Record 10 of Set 4 | avarua
# Processing Record 11 of Set 4 | codrington
# Processing Record 12 of Set 4 | payson
# Processing Record 13 of Set 4 | tadine
# Processing Record 14 of Set 4 | acapulco
# Processing Record 15 of Set 4 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 4 | sisimiut
# Processing Record 17 of Set 4 | ligayan
# Processing Record 18 of Set 4 | kushiro
# Processing Record 19 of Set 4 | zhangjiakou
# Processing Record 20 of Set 4 | namibe
# Processing Record 21 of Set 4 | sokoni
# Processing Record 22 of Set 4 | saa
# Processing Record 23 of Set 4 | verkhnevilyuysk
# Processing Record 24 of Set 4 | mogadishu
# Processing Record 25 of Set 4 | orbetello
# Processing Record 26 of Set 4 | lydenburg
# Processing Record 27 of Set 4 | lashio
# Processing Record 28 of Set 4 | zumpahuacan
# Processing Record 29 of Set 4 | ancud
# Processing Record 30 of Set 4 | dubbo
# Processing Record 31 of Set 4 | nguiu
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 4 | manhuacu
# Processing Record 33 of Set 4 | bahar
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | gat
# Processing Record 37 of Set 4 | coulommiers
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | gladstone
# Processing Record 40 of Set 4 | zhigalovo
# Processing Record 41 of Set 4 | marfino
# Processing Record 42 of Set 4 | vila velha
# Processing Record 43 of Set 4 | mount gambier
# Processing Record 44 of Set 4 | muli
# Processing Record 45 of Set 4 | narsaq
# Processing Record 46 of Set 4 | mulchen
# Processing Record 47 of Set 4 | ahipara
# Processing Record 48 of Set 4 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 4 | callaway
# Processing Record 50 of Set 4 | rawson
# Processing Record 1 of Set 5 | yulara
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | sunland park
# Processing Record 4 of Set 5 | boshnyakovo
# Processing Record 5 of Set 5 | poso
# Processing Record 6 of Set 5 | bose
# Processing Record 7 of Set 5 | barcelona
# Processing Record 8 of Set 5 | ust-ishim
# Processing Record 9 of Set 5 | tambopata
# Processing Record 10 of Set 5 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 5 | hamilton
# Processing Record 12 of Set 5 | yar
# Processing Record 13 of Set 5 | fortuna
# Processing Record 14 of Set 5 | plettenberg bay
# Processing Record 15 of Set 5 | hami
# Processing Record 16 of Set 5 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 5 | ukiah
# Processing Record 18 of Set 5 | srednekolymsk
# Processing Record 19 of Set 5 | nanortalik
# Processing Record 20 of Set 5 | svetlogorsk
# Processing Record 21 of Set 5 | kinablangan
# Processing Record 22 of Set 5 | mackay
# Processing Record 23 of Set 5 | port hedland
# Processing Record 24 of Set 5 | coquimbo
# Processing Record 25 of Set 5 | vrangel
# Processing Record 26 of Set 5 | puerto leguizamo
# Processing Record 27 of Set 5 | avera
# Processing Record 28 of Set 5 | carnarvon
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | korem
# Processing Record 31 of Set 5 | montemorelos
# Processing Record 32 of Set 5 | saskylakh
# Processing Record 33 of Set 5 | saint george
# Processing Record 34 of Set 5 | shu
# Processing Record 35 of Set 5 | rehoboth
# Processing Record 36 of Set 5 | abha
# Processing Record 37 of Set 5 | general pico
# Processing Record 38 of Set 5 | hofn
# Processing Record 39 of Set 5 | khormuj
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 5 | kaeo
# Processing Record 41 of Set 5 | keti bandar
# Processing Record 42 of Set 5 | henties bay
# Processing Record 43 of Set 5 | shache
# Processing Record 44 of Set 5 | lebu
# Processing Record 45 of Set 5 | inuvik
# Processing Record 46 of Set 5 | isangel
# Processing Record 47 of Set 5 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 5 | waingapu
# Processing Record 49 of Set 5 | bayji
# Processing Record 50 of Set 5 | mauganj
# Processing Record 1 of Set 6 | talcahuano
# Processing Record 2 of Set 6 | san cristobal
# Processing Record 3 of Set 6 | talnakh
# Processing Record 4 of Set 6 | segezha
# Processing Record 5 of Set 6 | thompson
# Processing Record 6 of Set 6 | artyk
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 6 | moose factory
# Processing Record 8 of Set 6 | yugorsk
# Processing Record 9 of Set 6 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 6 | floro
# Processing Record 11 of Set 6 | meulaboh
# Processing Record 12 of Set 6 | requena
# Processing Record 13 of Set 6 | udachnyy
# Processing Record 14 of Set 6 | olinda
# Processing Record 15 of Set 6 | husavik
# Processing Record 16 of Set 6 | port macquarie
# Processing Record 17 of Set 6 | aguimes
# Processing Record 18 of Set 6 | along
# Processing Record 19 of Set 6 | nome
# Processing Record 20 of Set 6 | north platte
# Processing Record 21 of Set 6 | doume
# Processing Record 22 of Set 6 | rybinsk
# Processing Record 23 of Set 6 | gbarnga
# Processing Record 24 of Set 6 | port blair
# Processing Record 25 of Set 6 | turukhansk
# Processing Record 26 of Set 6 | okato
# Processing Record 27 of Set 6 | jaciara
# Processing Record 28 of Set 6 | singleton
# Processing Record 29 of Set 6 | vitre
# Processing Record 30 of Set 6 | richards bay
# Processing Record 31 of Set 6 | serebryanyy bor
# Processing Record 32 of Set 6 | kawalu
# Processing Record 33 of Set 6 | haines junction
# Processing Record 34 of Set 6 | yeppoon
# Processing Record 35 of Set 6 | tautira
# Processing Record 36 of Set 6 | wiesmoor
# Processing Record 37 of Set 6 | itoman
# Processing Record 38 of Set 6 | lakes entrance
# Processing Record 39 of Set 6 | bubaque
# Processing Record 40 of Set 6 | nata
# Processing Record 41 of Set 6 | ko samui
# Processing Record 42 of Set 6 | abrau-dyurso
# Processing Record 43 of Set 6 | beyneu
# Processing Record 44 of Set 6 | sechura
# Processing Record 45 of Set 6 | millinocket
# Processing Record 46 of Set 6 | kailua
# Processing Record 47 of Set 6 | chau doc
# Processing Record 48 of Set 6 | anadyr
# Processing Record 49 of Set 6 | lokosovo
# Processing Record 50 of Set 6 | marawi
# Processing Record 1 of Set 7 | chandbali
# Processing Record 2 of Set 7 | aanekoski
# Processing Record 3 of Set 7 | kahului
# Processing Record 4 of Set 7 | pathein
# Processing Record 5 of Set 7 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 7 | awbari
# Processing Record 7 of Set 7 | shenjiamen
# Processing Record 8 of Set 7 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 7 | naryan-mar
# Processing Record 10 of Set 7 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 7 | khirkiya
# Processing Record 12 of Set 7 | balkanabat
# Processing Record 13 of Set 7 | santa isabel do rio negro
# Processing Record 14 of Set 7 | namatanai
# Processing Record 15 of Set 7 | roald
# Processing Record 16 of Set 7 | sungaipenuh
# Processing Record 17 of Set 7 | kavieng
# Processing Record 18 of Set 7 | saint quentin
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 7 | istra
# Processing Record 20 of Set 7 | buala
# Processing Record 21 of Set 7 | lagos
# Processing Record 22 of Set 7 | wolmaranstad
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 7 | ketchikan
# Processing Record 24 of Set 7 | marsa matruh
# Processing Record 25 of Set 7 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 7 | cagayan de tawi-tawi
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 7 | guerrero negro
# Processing Record 28 of Set 7 | san quintin
# Processing Record 29 of Set 7 | chifeng
# Processing Record 30 of Set 7 | anloga
# Processing Record 31 of Set 7 | jiuquan
# Processing Record 32 of Set 7 | zhigansk
# Processing Record 33 of Set 7 | olavarria
# Processing Record 34 of Set 7 | pushkinskiye gory
# Processing Record 35 of Set 7 | talawdi
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 7 | grimshaw
# Processing Record 37 of Set 7 | moron
# Processing Record 38 of Set 7 | honiara
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | hasaki
# Processing Record 41 of Set 7 | port moresby
# Processing Record 42 of Set 7 | trairi
# Processing Record 43 of Set 7 | ucluelet
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | jieshi
# Processing Record 46 of Set 7 | patnos
# Processing Record 47 of Set 7 | cururupu
# Processing Record 48 of Set 7 | bilibino
# Processing Record 49 of Set 7 | kavaratti
# Processing Record 50 of Set 7 | wielun
# Processing Record 1 of Set 8 | belaya gora
# Processing Record 2 of Set 8 | saint-louis
# Processing Record 3 of Set 8 | salym
# Processing Record 4 of Set 8 | faya
# Processing Record 5 of Set 8 | saint albans
# Processing Record 6 of Set 8 | yarmouth
# Processing Record 7 of Set 8 | constitucion
# Processing Record 8 of Set 8 | portland
# Processing Record 9 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 8 | tamandare
# Processing Record 11 of Set 8 | sola
# Processing Record 12 of Set 8 | longyearbyen
# Processing Record 13 of Set 8 | antigonish
# Processing Record 14 of Set 8 | saint-augustin
# Processing Record 15 of Set 8 | solovetskiy
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 8 | tartagal
# Processing Record 17 of Set 8 | miles city
# Processing Record 18 of Set 8 | maumere
# Processing Record 19 of Set 8 | samana
# Processing Record 20 of Set 8 | superior
# Processing Record 21 of Set 8 | marsh harbour
# Processing Record 22 of Set 8 | klamath falls
# Processing Record 23 of Set 8 | barahona
# Processing Record 24 of Set 8 | chuy
# Processing Record 25 of Set 8 | ilulissat
# Processing Record 26 of Set 8 | satitoa
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 8 | oparino
# Processing Record 28 of Set 8 | mehamn
# Processing Record 29 of Set 8 | dingle
# Processing Record 30 of Set 8 | gornopravdinsk
# Processing Record 31 of Set 8 | mbulu
# Processing Record 32 of Set 8 | colares
# Processing Record 33 of Set 8 | caravelas
# Processing Record 34 of Set 8 | umm durman
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 8 | xining
# Processing Record 36 of Set 8 | samarai
# Processing Record 37 of Set 8 | iqaluit
# Processing Record 38 of Set 8 | sogdiondon
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 8 | taoudenni
# Processing Record 40 of Set 8 | yazykovo
# Processing Record 41 of Set 8 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 8 | lorengau
# Processing Record 43 of Set 8 | guaymas
# Processing Record 44 of Set 8 | arlit
# Processing Record 45 of Set 8 | saravan
# Processing Record 46 of Set 8 | chernyshevskiy
# Processing Record 47 of Set 8 | arman
# Processing Record 48 of Set 8 | la primavera
# Processing Record 49 of Set 8 | algeciras
# Processing Record 50 of Set 8 | aksu
# Processing Record 1 of Set 9 | tazovskiy
# Processing Record 2 of Set 9 | okhotsk
# Processing Record 3 of Set 9 | slave lake
# Processing Record 4 of Set 9 | lompoc
# Processing Record 5 of Set 9 | kamina
# Processing Record 6 of Set 9 | grand gaube
# Processing Record 7 of Set 9 | lower hutt
# Processing Record 8 of Set 9 | esperance
# Processing Record 9 of Set 9 | loiza
# Processing Record 10 of Set 9 | ust-nera
# Processing Record 11 of Set 9 | port hawkesbury
# Processing Record 12 of Set 9 | bontang
# Processing Record 13 of Set 9 | jilib
# Processing Record 14 of Set 9 | porto seguro
# Processing Record 15 of Set 9 | mount isa
# Processing Record 16 of Set 9 | guajara-mirim
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 9 | geraldton
# Processing Record 18 of Set 9 | parnarama
# Processing Record 19 of Set 9 | gorno-chuyskiy
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 9 | makinsk
# Processing Record 21 of Set 9 | hihifo
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 9 | dir
# Processing Record 23 of Set 9 | puerto cortes
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 9 | lyantonde
# Processing Record 25 of Set 9 | gualeguaychu
# Processing Record 26 of Set 9 | morant bay
# Processing Record 27 of Set 9 | mangai
# Processing Record 28 of Set 9 | yerbogachen
# Processing Record 29 of Set 9 | huarmey
# Processing Record 30 of Set 9 | neyshabur
# Processing Record 31 of Set 9 | borlange
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 9 | smidovich
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | brewster
# Processing Record 35 of Set 9 | dakar
# Processing Record 36 of Set 9 | tibacuy
# Processing Record 37 of Set 9 | kigoma
# Processing Record 38 of Set 9 | champerico
# Processing Record 39 of Set 9 | hambantota
# Processing Record 40 of Set 9 | porto novo
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | hyeres
# Processing Record 43 of Set 9 | sambava
# Processing Record 44 of Set 9 | urdzhar
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 9 | oriximina
# Processing Record 46 of Set 9 | los llanos de aridane
# Processing Record 47 of Set 9 | baculin
# Processing Record 48 of Set 9 | mednogorsk
# Processing Record 49 of Set 9 | bikin
# Processing Record 50 of Set 9 | pacific grove
# Processing Record 1 of Set 10 | yarada
# Processing Record 2 of Set 10 | necochea
# Processing Record 3 of Set 10 | ixtapa
# Processing Record 4 of Set 10 | thunder bay
# Processing Record 5 of Set 10 | port elizabeth
# Processing Record 6 of Set 10 | beni
# Processing Record 7 of Set 10 | a coruna
# Processing Record 8 of Set 10 | eureka
# Processing Record 9 of Set 10 | cabatuan
# Processing Record 10 of Set 10 | churapcha
# Processing Record 11 of Set 10 | tabiauea
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 10 | vostok
# Processing Record 13 of Set 10 | alekseyevsk
# Processing Record 14 of Set 10 | bam
# Processing Record 15 of Set 10 | port lincoln
# Processing Record 16 of Set 10 | ust-uda
# Processing Record 17 of Set 10 | catamarca
# Processing Record 18 of Set 10 | bagotville
# Processing Record 19 of Set 10 | espumoso
# Processing Record 20 of Set 10 | kashi
# Processing Record 21 of Set 10 | scottsbluff
# Processing Record 22 of Set 10 | maramba
# Processing Record 23 of Set 10 | zonguldak
# Processing Record 24 of Set 10 | kismayo
# Processing Record 25 of Set 10 | maragogi
# Processing Record 26 of Set 10 | billings
# Processing Record 27 of Set 10 | chiredzi
# Processing Record 28 of Set 10 | umm kaddadah
# Processing Record 29 of Set 10 | pangody
# Processing Record 30 of Set 10 | yumen
# Processing Record 31 of Set 10 | roebourne
# Processing Record 32 of Set 10 | kamloops
# Processing Record 33 of Set 10 | santa rosa
# Processing Record 34 of Set 10 | geneva
# Processing Record 35 of Set 10 | nema
# Processing Record 36 of Set 10 | poum
# Processing Record 37 of Set 10 | mandalgovi
# Processing Record 38 of Set 10 | preobrazheniye
# Processing Record 39 of Set 10 | rawlins
# Processing Record 40 of Set 10 | shizunai
# Processing Record 41 of Set 10 | joaquim gomes
# Processing Record 42 of Set 10 | micheweni
# Processing Record 43 of Set 10 | bac lieu
# Processing Record 44 of Set 10 | hokitika
# Processing Record 45 of Set 10 | cap malheureux
# Processing Record 46 of Set 10 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 10 | olafsvik
# Processing Record 48 of Set 10 | vondrozo
# Processing Record 49 of Set 10 | baracoa
# Processing Record 50 of Set 10 | farah
# Processing Record 1 of Set 11 | college
# Processing Record 2 of Set 11 | erenhot
# Processing Record 3 of Set 11 | north bend
# Processing Record 4 of Set 11 | rincon
# Processing Record 5 of Set 11 | atasu
# Processing Record 6 of Set 11 | arantangi
# Processing Record 7 of Set 11 | tubruq
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 11 | klaksvik
# Processing Record 9 of Set 11 | vanavara
# Processing Record 10 of Set 11 | jinka
# Processing Record 11 of Set 11 | yuanping
# Processing Record 12 of Set 11 | carahue
# Processing Record 13 of Set 11 | abdulino
# Processing Record 14 of Set 11 | tual
# Processing Record 15 of Set 11 | manggar
# Processing Record 16 of Set 11 | tilichiki
# Processing Record 17 of Set 11 | guerrero
# Processing Record 18 of Set 11 | skjervoy
# Processing Record 19 of Set 11 | novobureyskiy
# Processing Record 20 of Set 11 | sobolevo
# Processing Record 21 of Set 11 | sergeyevka
# Processing Record 22 of Set 11 | harvard
# Processing Record 23 of Set 11 | jasdan
# Processing Record 24 of Set 11 | gorontalo
# Processing Record 25 of Set 11 | verkh-usugli
# Processing Record 26 of Set 11 | warqla
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 11 | athabasca
# Processing Record 28 of Set 11 | kutum
# Processing Record 29 of Set 11 | linguere
# Processing Record 30 of Set 11 | dudinka
# Processing Record 31 of Set 11 | kano
# Processing Record 32 of Set 11 | cayenne
# Processing Record 33 of Set 11 | am timan
# Processing Record 34 of Set 11 | cosolapa
# Processing Record 35 of Set 11 | araure
# Processing Record 36 of Set 11 | vao
# Processing Record 37 of Set 11 | save
# Processing Record 38 of Set 11 | quthing
# Processing Record 39 of Set 11 | helong
# Processing Record 40 of Set 11 | sibolga
# Processing Record 41 of Set 11 | juneau
# Processing Record 42 of Set 11 | sioux lookout
# Processing Record 43 of Set 11 | adiake
# Processing Record 44 of Set 11 | manbij
# Processing Record 45 of Set 11 | balabac
# Processing Record 46 of Set 11 | bokspits
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 11 | vardo
# Processing Record 48 of Set 11 | parana
# Processing Record 49 of Set 11 | maniitsoq
# Processing Record 50 of Set 11 | harnoli
# Processing Record 1 of Set 12 | shimoda
# Processing Record 2 of Set 12 | craig
# Processing Record 3 of Set 12 | santa maria
# Processing Record 4 of Set 12 | yunjinghong
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 12 | barcelos
# Processing Record 6 of Set 12 | pitimbu
# Processing Record 7 of Set 12 | itatiaia
# Processing Record 8 of Set 12 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 12 | rumoi
# Processing Record 10 of Set 12 | fairbanks
# Processing Record 11 of Set 12 | gurgan
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 12 | pingxiang
# Processing Record 13 of Set 12 | carnduff
# Processing Record 14 of Set 12 | khor
# Processing Record 15 of Set 12 | fomboni
# Processing Record 16 of Set 12 | nicoya
# Processing Record 17 of Set 12 | coahuayana
# Processing Record 18 of Set 12 | bolivar
# Processing Record 19 of Set 12 | mahajanga
# Processing Record 20 of Set 12 | wampusirpi
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 12 | tulun
# Processing Record 22 of Set 12 | rawannawi
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 12 | puerto penasco
# Processing Record 24 of Set 12 | follebu
# Processing Record 25 of Set 12 | ban nahin
# Processing Record 26 of Set 12 | sinkat
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 12 | beloha
# Processing Record 28 of Set 12 | pacasmayo
# Processing Record 29 of Set 12 | iranshahr
# Processing Record 30 of Set 12 | conceicao do araguaia
# Processing Record 31 of Set 12 | great falls
# Processing Record 32 of Set 12 | basco
# Processing Record 33 of Set 12 | iracoubo
# Processing Record 34 of Set 12 | thinadhoo
# Processing Record 35 of Set 12 | japura
# Processing Record 36 of Set 12 | monticello
# Processing Record 37 of Set 12 | feldkirchen an der donau
# Processing Record 38 of Set 12 | aswan
# Processing Record 39 of Set 12 | mergui
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 12 | puerto colombia
# Processing Record 41 of Set 12 | sao filipe
# Processing Record 42 of Set 12 | mayo
# Processing Record 43 of Set 12 | paso de carrasco
# Processing Record 44 of Set 12 | pochutla
# Processing Record 45 of Set 12 | nantucket
# Processing Record 46 of Set 12 | berdigestyakh
# Processing Record 47 of Set 12 | rogers
# Processing Record 48 of Set 12 | toktogul
# Processing Record 49 of Set 12 | jinan
# Processing Record 50 of Set 12 | viedma
# Processing Record 1 of Set 13 | massakory
# Processing Record 2 of Set 13 | tidore
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 13 | andenes
# Processing Record 4 of Set 13 | aurillac
# Processing Record 5 of Set 13 | grindavik
# Processing Record 6 of Set 13 | dunedin
# Processing Record 7 of Set 13 | chernyshevsk
# Processing Record 8 of Set 13 | cozumel
# Processing Record 9 of Set 13 | beverwijk
# Processing Record 10 of Set 13 | nemuro
# Processing Record 11 of Set 13 | okha
# Processing Record 12 of Set 13 | palkino
# Processing Record 13 of Set 13 | mafinga
# Processing Record 14 of Set 13 | charters towers
# Processing Record 15 of Set 13 | lazaro cardenas
# Processing Record 16 of Set 13 | puerto madero
# Processing Record 17 of Set 13 | san ignacio
# Processing Record 18 of Set 13 | tanete
# Processing Record 19 of Set 13 | saint-joseph
# Processing Record 20 of Set 13 | opuwo
# Processing Record 21 of Set 13 | sawang daen din
# Processing Record 22 of Set 13 | innsbruck
# Processing Record 23 of Set 13 | bambous virieux
# Processing Record 24 of Set 13 | truro
# Processing Record 25 of Set 13 | cabras
# Processing Record 26 of Set 13 | serebryansk
# Processing Record 27 of Set 13 | nautla
# Processing Record 28 of Set 13 | kabanjahe
# Processing Record 29 of Set 13 | tshikapa
# Processing Record 30 of Set 13 | alakurtti
# Processing Record 31 of Set 13 | atambua
# Processing Record 32 of Set 13 | beringovskiy
# Processing Record 33 of Set 13 | imperia
# Processing Record 34 of Set 13 | oussouye
# Processing Record 35 of Set 13 | savino
# Processing Record 36 of Set 13 | chumikan
# Processing Record 37 of Set 13 | birao
# Processing Record 38 of Set 13 | bria
# Processing Record 39 of Set 13 | amahai
# Processing Record 40 of Set 13 | batagay-alyta
# Processing Record 41 of Set 13 | lakhdenpokhya
# Processing Record 42 of Set 13 | paciran
# Processing Record 43 of Set 13 | moranbah
# Processing Record 44 of Set 13 | bafoulabe
# Processing Record 45 of Set 13 | bauchi
# Processing Record 46 of Set 13 | yokadouma
# Processing Record 47 of Set 13 | canutama
# Processing Record 48 of Set 13 | ventnor city
# Processing Record 49 of Set 13 | la esperanza
# Processing Record 50 of Set 13 | sao joao da barra
# Processing Record 1 of Set 14 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 14 | panaba
# Processing Record 3 of Set 14 | mahibadhoo
# Processing Record 4 of Set 14 | ambilobe
# Processing Record 5 of Set 14 | ramtek
# Processing Record 6 of Set 14 | gulshat
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 14 | dali
# Processing Record 8 of Set 14 | natchitoches
# Processing Record 9 of Set 14 | cabedelo
# Processing Record 10 of Set 14 | comodoro rivadavia
# Processing Record 11 of Set 14 | oakdale
# Processing Record 12 of Set 14 | ksenyevka
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 14 | jumla
# Processing Record 14 of Set 14 | robertsport
# Processing Record 15 of Set 14 | enfield
# Processing Record 16 of Set 14 | atar
# Processing Record 17 of Set 14 | quelimane
# Processing Record 18 of Set 14 | jiayuguan
# Processing Record 19 of Set 14 | ratnagiri
# Processing Record 20 of Set 14 | hermitage
# Processing Record 21 of Set 14 | orocue
# Processing Record 22 of Set 14 | flin flon
# Processing Record 23 of Set 14 | klyuchi
# Processing Record 24 of Set 14 | kudahuvadhoo
# Processing Record 25 of Set 14 | hof
# Processing Record 26 of Set 14 | rudbar
# Processing Record 27 of Set 14 | bud
# Processing Record 28 of Set 14 | maun
# Processing Record 29 of Set 14 | pierre
# Processing Record 30 of Set 14 | uromi
# Processing Record 31 of Set 14 | havoysund
# Processing Record 32 of Set 14 | troitsk
# Processing Record 33 of Set 14 | south lake tahoe
# Processing Record 34 of Set 14 | darnah
# Processing Record 35 of Set 14 | yangambi
# Processing Record 36 of Set 14 | pangnirtung
# Processing Record 37 of Set 14 | tabas
# Processing Record 38 of Set 14 | nueva italia de ruiz
# Processing Record 39 of Set 14 | pisco
# Processing Record 40 of Set 14 | yeletskiy
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 14 | zhangye
# Processing Record 42 of Set 14 | pionerskiy
# Processing Record 43 of Set 14 | talara
# Processing Record 44 of Set 14 | beisfjord
# Processing Record 45 of Set 14 | del rio
# Processing Record 46 of Set 14 | karratha
# Processing Record 47 of Set 14 | sovetskiy
# Processing Record 48 of Set 14 | tiruvottiyur
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 14 | takestan
# Processing Record 50 of Set 14 | denpasar
# Processing Record 1 of Set 15 | cervo
# Processing Record 2 of Set 15 | luanda
# Processing Record 3 of Set 15 | samalaeulu
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 15 | fort saint john
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 15 | ulladulla
# Processing Record 6 of Set 15 | mbanza-ngungu
# Processing Record 7 of Set 15 | dodge city
# Processing Record 8 of Set 15 | zanjan
# Processing Record 9 of Set 15 | kibaya
# Processing Record 10 of Set 15 | itapuranga
# Processing Record 11 of Set 15 | pontes e lacerda
# Processing Record 12 of Set 15 | veinticinco de mayo
# Processing Record 13 of Set 15 | bethanien
# Processing Record 14 of Set 15 | balurghat
# Processing Record 15 of Set 15 | bend
# Processing Record 16 of Set 15 | nelson bay
# Processing Record 17 of Set 15 | tortoli
# Processing Record 18 of Set 15 | kuytun
# Processing Record 19 of Set 15 | haibowan
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 15 | saint-pierre
# Processing Record 21 of Set 15 | bezhanitsy
# Processing Record 22 of Set 15 | popondetta
# Processing Record 23 of Set 15 | mawlaik
# Processing Record 24 of Set 15 | surt
# Processing Record 25 of Set 15 | nago
# Processing Record 26 of Set 15 | tynda
# Processing Record 27 of Set 15 | jinxiang
# Processing Record 28 of Set 15 | bhilwara
# Processing Record 29 of Set 15 | nakhon phanom
# Processing Record 30 of Set 15 | neustrelitz
# Processing Record 31 of Set 15 | contamana
# Processing Record 32 of Set 15 | moca
# Processing Record 33 of Set 15 | korla
# Processing Record 34 of Set 15 | singaraja
# Processing Record 35 of Set 15 | pathalgaon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Kapaa      US  22.0752 -159.3190     66.18        78          20
# 1  Punta Arenas      CL -53.1500  -70.9167     66.31        52          75
# 2    Ust-Tsilma      RU  65.4410   52.1498     -9.33       100          46
# 3       Camacha      PT  33.0833  -16.3333     66.52        72          20
# 4        Maceio      BR  -9.6658  -35.7353     90.84        40          40
#
#    Wind Speed  City Description
# 0        4.61        few clouds
# 1       35.68     broken clouds
# 2        3.69  scattered clouds
# 3       20.71        few clouds
# 4       13.80  scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
